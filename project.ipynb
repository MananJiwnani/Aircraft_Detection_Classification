# %% [markdown]
# ### Printing model names to get all classes.

# %%
from ultralytics import YOLO

model = YOLO("yolo26x-obb.pt")
print(model.names)
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\asus\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# {0: 'plane', 1: 'ship', 2: 'storage tank', 3: 'baseball diamond', 4: 'tennis court', 5: 'basketball court', 6: 'ground track field', 7: 'harbor', 8: 'bridge', 9: 'large vehicle', 10: 'small vehicle', 11: 'helicopter', 12: 'roundabout', 13: 'soccer ball field', 14: 'swimming pool'}

# %% [markdown]
# ### Taking only class 0 for airplane detection.

# %%
results = model.predict(
    source="./dataset",
    save=True,
    classes=[0]
)
# Out:
# image 1/3 c:\Users\asus\satellite\project\dataset\1.jpeg: 1024x1024 1 plane, 4799.3ms
# image 2/3 c:\Users\asus\satellite\project\dataset\2.jpeg: 1024x1024 1 plane, 4136.6ms
# image 3/3 c:\Users\asus\satellite\project\dataset\3.jpeg: 1024x1024 4 planes, 4021.6ms
# Speed: 23.0ms preprocess, 4319.2ms inference, 0.9ms postprocess per image at shape (1, 3, 1024, 1024)
# Results saved to C:\Users\asus\satellite\project\runs\obb\predict
